# %% [markdown]
# #### By Anthony (AJ) Buttitta

# %% [markdown]
# ## Import Libraries

# %%
# Common imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Downloads/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csvDownloads/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv
# df = pd.read_csv('Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv')
# df

# %%
oilprices = pd.read_csv(r"C:\Users\ajbut\Downloads\crude-oil-prices.csv")
oilprices
# Out:
#     Entity      Code  Year  Oil - Crude prices since 1861 (current $)
# 0    World  OWID_WRL  1861                                   3.081610
# 1    World  OWID_WRL  1862                                   6.603450
# 2    World  OWID_WRL  1863                                  19.810351
# 3    World  OWID_WRL  1864                                  50.689343
# 4    World  OWID_WRL  1865                                  41.444511
# ..     ...       ...   ...                                        ...
# 156  World  OWID_WRL  2017                                 340.816255
# 157  World  OWID_WRL  2018                                 448.468958
# 158  World  OWID_WRL  2019                                 403.820283
# 159  World  OWID_WRL  2020                                 263.121349
# 160  World  OWID_WRL  2021                                 445.964912
#
# [161 rows x 4 columns]

# %%
energysource = pd.read_csv(r"C:\Users\ajbut\Downloads\primary-energy-source-bar.csv")
energysource
# Out:
#       Entity      Code  Year  Coal Consumption - TWh  Oil Consumption - TWh  \
# 0     Africa       NaN  1965              323.496124             341.262756
# 1     Africa       NaN  1966              323.122192             369.486572
# 2     Africa       NaN  1967              330.291565             368.125244
# 3     Africa       NaN  1968              343.512909             389.199860
# 4     Africa       NaN  1969              346.642944             396.922852
# ...      ...       ...   ...                     ...                    ...
# 6155   World  OWID_WRL  2017            43751.675781           52515.542969
# 6156   World  OWID_WRL  2018            44315.875000           53250.621094
# 6157   World  OWID_WRL  2019            43699.886719           53368.628906
# 6158   World  OWID_WRL  2020            41963.964844           48380.710938
# 6159   World  OWID_WRL  2021            44473.195312           51170.472656
#
# ...

# %%
cpi = pd.read_csv(r"C:\Users\ajbut\Downloads\PRICES_CPI_28102022032353054.csv")
cpi
# Out:
#        LOCATION                                          Country   SUBJECT  \
# 0           GBR                                   United Kingdom  CPALTT01
# 1           GBR                                   United Kingdom  CPALTT01
# 2           GBR                                   United Kingdom  CPALTT01
# 3           GBR                                   United Kingdom  CPALTT01
# 4           GBR                                   United Kingdom  CPALTT01
# ...         ...                                              ...       ...
# 2435  EU27_2020  European Union – 27 countries (from 01/02/2020)  CPALTT01
# 2436  EU27_2020  European Union – 27 countries (from 01/02/2020)  CPALTT01
# 2437  EU27_2020  European Union – 27 countries (from 01/02/2020)  CPALTT01
# 2438  EU27_2020  European Union – 27 countries (from 01/02/2020)  CPALTT01
# 2439  EU27_2020  European Union – 27 countries (from 01/02/2020)  CPALTT01
#
# ...

# %%
oilshare = pd.read_csv(r"C:\Users\ajbut\Downloads\oil-share-energy.csv")
oilshare
# Out:
#       Entity      Code  Year  Oil (% equivalent primary energy)
# 0     Africa       NaN  1965                          47.700935
# 1     Africa       NaN  1966                          49.321323
# 2     Africa       NaN  1967                          48.639896
# 3     Africa       NaN  1968                          48.686363
# 4     Africa       NaN  1969                          48.322144
# ...      ...       ...   ...                                ...
# 6155   World  OWID_WRL  2017                          33.363041
# 6156   World  OWID_WRL  2018                          32.916954
# 6157   World  OWID_WRL  2019                          32.706581
# 6158   World  OWID_WRL  2020                          30.880657
# 6159   World  OWID_WRL  2021                          30.952438
#
# [6160 rows x 4 columns]

# %% [markdown]
# Dataframes...
# 1) oilprices
# 2) energysource
# 3) cpi
# 4) oilshare

# %%
oilprices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Entity                                     161 non-null    object
#  1   Code                                       161 non-null    object
#  2   Year                                       161 non-null    int64
#  3   Oil - Crude prices since 1861 (current $)  161 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.2+ KB

# %%
oilprices['Year'] =  pd.to_datetime(oilprices['Year'],format= '%Y')

# %%
oilprices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Entity                                     161 non-null    object
#  1   Code                                       161 non-null    object
#  2   Year                                       161 non-null    datetime64[ns]
#  3   Oil - Crude prices since 1861 (current $)  161 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 5.2+ KB

# %%
energysource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6160 entries, 0 to 6159
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Entity                     6160 non-null   object
#  1   Code                       4299 non-null   object
#  2   Year                       6160 non-null   int64
#  3   Coal Consumption - TWh     6134 non-null   float64
#  4   Oil Consumption - TWh      6160 non-null   float64
#  5   Gas Consumption - TWh      6094 non-null   float64
#  6   Nuclear Consumption - TWh  5624 non-null   float64
#  7   Hydro Consumption - TWh    6153 non-null   float64
#  8   Wind Consumption - TWh     5939 non-null   float64
#  9   Solar Consumption - TWh    5924 non-null   float64
#  10  Geo Biomass Other - TWh    5948 non-null   float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 529.5+ KB

# %%
energysource['Year'] =  pd.to_datetime(energysource['Year'],format= '%Y')

# %%
energysource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6160 entries, 0 to 6159
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Entity                     6160 non-null   object
#  1   Code                       4299 non-null   object
#  2   Year                       6160 non-null   datetime64[ns]
#  3   Coal Consumption - TWh     6134 non-null   float64
#  4   Oil Consumption - TWh      6160 non-null   float64
#  5   Gas Consumption - TWh      6094 non-null   float64
#  6   Nuclear Consumption - TWh  5624 non-null   float64
#  7   Hydro Consumption - TWh    6153 non-null   float64
#  8   Wind Consumption - TWh     5939 non-null   float64
#  9   Solar Consumption - TWh    5924 non-null   float64
#  10  Geo Biomass Other - TWh    5948 non-null   float64
# dtypes: datetime64[ns](1), float64(8), object(2)
# memory usage: 529.5+ KB

# %%
cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2440 entries, 0 to 2439
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   LOCATION               2440 non-null   object
#  1   Country                2440 non-null   object
#  2   SUBJECT                2440 non-null   object
#  3   Subject                2440 non-null   object
#  4   MEASURE                2440 non-null   object
#  5   Measure                2440 non-null   object
#  6   FREQUENCY              2440 non-null   object
#  7   Frequency              2440 non-null   object
#  8   TIME                   2440 non-null   int64
#  9   Time                   2440 non-null   int64
#  10  Unit Code              2440 non-null   object
#  11  Unit                   2440 non-null   object
#  12  PowerCode Code         2440 non-null   int64
#  13  PowerCode              2440 non-null   object
# ...

# %%
cpi['Year'] =  pd.to_datetime(cpi['Time'],format= '%Y')
# cpi.replace({'Country': {"China (People's Republic of)": "China"}})
# cpi.replace({'Country': {"Korea": "South Korea"}})

cpi['Country'] = cpi['Country'].replace(["China (People's Republic of)"], 'China')
cpi['Country'] = cpi['Country'].replace(["Korea"], 'South Korea')

# %%
cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2440 entries, 0 to 2439
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   LOCATION               2440 non-null   object
#  1   Country                2440 non-null   object
#  2   SUBJECT                2440 non-null   object
#  3   Subject                2440 non-null   object
#  4   MEASURE                2440 non-null   object
#  5   Measure                2440 non-null   object
#  6   FREQUENCY              2440 non-null   object
#  7   Frequency              2440 non-null   object
#  8   TIME                   2440 non-null   int64
#  9   Time                   2440 non-null   int64
#  10  Unit Code              2440 non-null   object
#  11  Unit                   2440 non-null   object
#  12  PowerCode Code         2440 non-null   int64
#  13  PowerCode              2440 non-null   object
# ...

# %%
oilshare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6160 entries, 0 to 6159
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Entity                             6160 non-null   object
#  1   Code                               4299 non-null   object
#  2   Year                               6160 non-null   int64
#  3   Oil (% equivalent primary energy)  6160 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 192.6+ KB

# %%
oilshare['Year'] =  pd.to_datetime(oilshare['Year'],format= '%Y')

# %%
oilshare.tail()
# Out:
#      Entity      Code       Year  Oil (% equivalent primary energy)
# 6155  World  OWID_WRL 2017-01-01                          33.363041
# 6156  World  OWID_WRL 2018-01-01                          32.916954
# 6157  World  OWID_WRL 2019-01-01                          32.706581
# 6158  World  OWID_WRL 2020-01-01                          30.880657
# 6159  World  OWID_WRL 2021-01-01                          30.952438

# %%
oilshare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6160 entries, 0 to 6159
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Entity                             6160 non-null   object
#  1   Code                               4299 non-null   object
#  2   Year                               6160 non-null   datetime64[ns]
#  3   Oil (% equivalent primary energy)  6160 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 192.6+ KB

# %%
oilprices['Year'] = oilprices['Year'].dt.strftime('%Y')

# %%
energysource['Year'] = energysource['Year'].dt.strftime('%Y')

# %%
cpi['Year'] = cpi['Year'].dt.strftime('%Y')

# %%
oilshare['Year'] = oilshare['Year'].dt.strftime('%Y')

# %%
oilprices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Entity                                     161 non-null    object
#  1   Code                                       161 non-null    object
#  2   Year                                       161 non-null    object
#  3   Oil - Crude prices since 1861 (current $)  161 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 5.2+ KB

# %%
oilprices = oilprices.drop(columns=['Entity', 'Code'])

# %%
oilshare =  oilshare.drop(columns=['Code'])

# %%
energysource = energysource.drop(columns=['Code'])

# %%
cpi = cpi.drop(columns=['LOCATION', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME', #'Country',
                        'Unit Code', 'PowerCode Code','Reference Period Code',
                        'Reference Period','Flag Codes', 'Flags'])

# %%
cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2440 entries, 0 to 2439
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    2440 non-null   object
#  1   Subject    2440 non-null   object
#  2   Measure    2440 non-null   object
#  3   Frequency  2440 non-null   object
#  4   Time       2440 non-null   int64
#  5   Unit       2440 non-null   object
#  6   PowerCode  2440 non-null   object
#  7   Value      2440 non-null   float64
#  8   Year       2440 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 171.7+ KB

# %%
cpi.head()
# Out:
#           Country                 Subject  \
# 0  United Kingdom  CPI: 01-12 - All items
# 1  United Kingdom  CPI: 01-12 - All items
# 2  United Kingdom  CPI: 01-12 - All items
# 3  United Kingdom  CPI: 01-12 - All items
# 4  United Kingdom  CPI: 01-12 - All items
#
#                                   Measure Frequency  Time        Unit  \
# 0  Percentage change from previous period    Annual  1965  Percentage
# 1  Percentage change from previous period    Annual  1966  Percentage
# 2  Percentage change from previous period    Annual  1967  Percentage
# 3  Percentage change from previous period    Annual  1968  Percentage
# 4  Percentage change from previous period    Annual  1969  Percentage
#
#   PowerCode     Value  Year
# 0     Units  4.773771  1965
# 1     Units  3.909618  1966
# 2     Units  2.482117  1967
# 3     Units  4.697424  1968
# 4     Units  5.446667  1969

# %%
df1 = oilshare.merge(oilprices, how="outer", on="Year")

# %%
cpi["Entity"] = cpi["Country"]

# %%
df1 = df1[df1['Entity'].notna()]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6160 entries, 0 to 6159
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Entity                                     6160 non-null   object
#  1   Year                                       6160 non-null   object
#  2   Oil (% equivalent primary energy)          6160 non-null   float64
#  3   Oil - Crude prices since 1861 (current $)  6160 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 240.6+ KB

# %%
df1.describe()
# Out:
#        Oil (% equivalent primary energy)  \
# count                        6160.000000
# mean                           48.273675
# std                            20.287305
# min                             7.663339
# 25%                            34.255177
# 50%                            44.310562
# 75%                            61.897700
# max                           100.000000
#
#        Oil - Crude prices since 1861 (current $)
# count                                6160.000000
# mean                                  222.109680
# std                                   190.693723
# min                                    11.320200
# 25%                                    90.750272
# 50%                                   157.371259
# 75%                                   340.816255
# max                                   702.290747

# %%
df1.head()
# Out:
#         Entity  Year  Oil (% equivalent primary energy)  \
# 0       Africa  1965                          47.700935
# 1  Africa (BP)  1965                          47.700939
# 2      Algeria  1965                          62.036282
# 3    Argentina  1965                          83.772102
# 4         Asia  1965                          41.695137
#
#    Oil - Crude prices since 1861 (current $)
# 0                                    11.3202
# 1                                    11.3202
# 2                                    11.3202
# 3                                    11.3202
# 4                                    11.3202

# %%
df1.tail(250)
# Out:
#                               Entity  Year  Oil (% equivalent primary energy)  \
# 5910                        Slovenia  2019                          37.539398
# 5911                    South Africa  2019                          22.010111
# 5912                   South America  2019                          37.485073
# 5913                     South Korea  2019                          42.787041
# 5914  South and Central America (BP)  2019                          40.618801
# ...                              ...   ...                                ...
# 6155                      Uzbekistan  2021                           8.707985
# 6156                       Venezuela  2021                          29.057194
# 6157                         Vietnam  2021                          21.656002
# 6158             Western Africa (BP)  2021                          56.989258
# 6159                           World  2021                          30.952438
#
# ...

# %%
# Use pandas.merge() on multiple columns
#df2 = df1.merge(cpi, how="left", on=['Entity'])
df2 = cpi.merge(df1,how='left', on = ['Entity', 'Year'])

# %%
df2.tail()
# Out:
#                                               Country                 Subject  \
# 2435  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
# 2436  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
# 2437  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
# 2438  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
# 2439  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
#
#                                      Measure Frequency  Time        Unit  \
# 2435  Percentage change from previous period    Annual  2017  Percentage
# 2436  Percentage change from previous period    Annual  2018  Percentage
# 2437  Percentage change from previous period    Annual  2019  Percentage
# 2438  Percentage change from previous period    Annual  2020  Percentage
# 2439  Percentage change from previous period    Annual  2021  Percentage
#
# ...

# %%
df1.Entity.nunique()
# Out:
# 114

# %%
cpi.Entity.nunique()
# Out:
# 52

# %%
energysource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6160 entries, 0 to 6159
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Entity                     6160 non-null   object
#  1   Year                       6160 non-null   object
#  2   Coal Consumption - TWh     6134 non-null   float64
#  3   Oil Consumption - TWh      6160 non-null   float64
#  4   Gas Consumption - TWh      6094 non-null   float64
#  5   Nuclear Consumption - TWh  5624 non-null   float64
#  6   Hydro Consumption - TWh    6153 non-null   float64
#  7   Wind Consumption - TWh     5939 non-null   float64
#  8   Solar Consumption - TWh    5924 non-null   float64
#  9   Geo Biomass Other - TWh    5948 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 481.4+ KB

# %%
df3 = df2.merge(energysource,how='left', on = ['Entity', 'Year'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2440 entries, 0 to 2439
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    2440 non-null   object
#  1   Subject                                    2440 non-null   object
#  2   Measure                                    2440 non-null   object
#  3   Frequency                                  2440 non-null   object
#  4   Time                                       2440 non-null   int64
#  5   Unit                                       2440 non-null   object
#  6   PowerCode                                  2440 non-null   object
#  7   Value                                      2440 non-null   float64
#  8   Year                                       2440 non-null   object
#  9   Entity                                     2440 non-null   object
# ...

# %%
df3.tail()
# Out:
#                                               Country                 Subject  \
# 2435  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
# 2436  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
# 2437  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
# 2438  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
# 2439  European Union – 27 countries (from 01/02/2020)  CPI: 01-12 - All items
#
#                                      Measure Frequency  Time        Unit  \
# 2435  Percentage change from previous period    Annual  2017  Percentage
# 2436  Percentage change from previous period    Annual  2018  Percentage
# 2437  Percentage change from previous period    Annual  2019  Percentage
# 2438  Percentage change from previous period    Annual  2020  Percentage
# 2439  Percentage change from previous period    Annual  2021  Percentage
#
# ...

# %%
df3.describe()
# Out:
#               Time        Value  Oil (% equivalent primary energy)  \
# count  2440.000000  2440.000000                        2045.000000
# mean   1996.104508    15.675527                          44.992130
# std      15.796605   103.750806                          15.464904
# min    1965.000000    -7.633931                          12.758014
# 25%    1983.000000     2.001558                          34.363209
# 50%    1998.000000     3.879116                          43.565544
# 75%    2010.000000     8.836628                          54.746033
# max    2021.000000  2947.733000                          99.967522
#
#        Oil - Crude prices since 1861 (current $)  Coal Consumption - TWh  \
# count                                2045.000000             2045.000000
# mean                                  235.826365              612.824208
# std                                   192.973567             2192.814773
# ...

# %%
df3.head()
# Out:
#           Country                 Subject  \
# 0  United Kingdom  CPI: 01-12 - All items
# 1  United Kingdom  CPI: 01-12 - All items
# 2  United Kingdom  CPI: 01-12 - All items
# 3  United Kingdom  CPI: 01-12 - All items
# 4  United Kingdom  CPI: 01-12 - All items
#
#                                   Measure Frequency  Time        Unit  \
# 0  Percentage change from previous period    Annual  1965  Percentage
# 1  Percentage change from previous period    Annual  1966  Percentage
# 2  Percentage change from previous period    Annual  1967  Percentage
# 3  Percentage change from previous period    Annual  1968  Percentage
# 4  Percentage change from previous period    Annual  1969  Percentage
#
#   PowerCode     Value  Year          Entity  \
# 0     Units  4.773771  1965  United Kingdom
# 1     Units  3.909618  1966  United Kingdom
# 2     Units  2.482117  1967  United Kingdom
# 3     Units  4.697424  1968  United Kingdom
# 4     Units  5.446667  1969  United Kingdom
#
# ...

# %%
df3["CPI"] =df3["Value"]

# %%
df3 = df3.drop(columns=['Measure', 'Frequency', "PowerCode", "Value","Time"])

# %%
df3 = df3[df3['Entity'].notna()]

# %%
df3.corr()
# Out:
#                                            Oil (% equivalent primary energy)  \
# Oil (% equivalent primary energy)                                   1.000000
# Oil - Crude prices since 1861 (current $)                          -0.281573
# Coal Consumption - TWh                                             -0.243326
# Oil Consumption - TWh                                              -0.078860
# Gas Consumption - TWh                                              -0.152831
# Nuclear Consumption - TWh                                          -0.144385
# Hydro Consumption - TWh                                            -0.273478
# Wind Consumption - TWh                                             -0.151087
# Solar Consumption - TWh                                            -0.123340
# Geo Biomass Other - TWh                                            -0.178364
# CPI                                                                 0.031195
#
# ...

# %%
df3.head()
# Out:
#           Country                 Subject        Unit  Year          Entity  \
# 0  United Kingdom  CPI: 01-12 - All items  Percentage  1965  United Kingdom
# 1  United Kingdom  CPI: 01-12 - All items  Percentage  1966  United Kingdom
# 2  United Kingdom  CPI: 01-12 - All items  Percentage  1967  United Kingdom
# 3  United Kingdom  CPI: 01-12 - All items  Percentage  1968  United Kingdom
# 4  United Kingdom  CPI: 01-12 - All items  Percentage  1969  United Kingdom
#
#    Oil (% equivalent primary energy)  \
# 0                          38.239796
# 1                          40.769749
# 2                          43.800892
# 3                          44.765903
# 4                          46.437191
#
#    Oil - Crude prices since 1861 (current $)  Coal Consumption - TWh  \
# 0                                    11.3202             1365.327148
# 1                                    11.3202             1299.419922
# 2                                    11.3202             1213.834717
# ...

# %%
points = df3.Entity.unique()

#sort values smallest to largest
points.sort()

#display sorted values
points
# Out:
# array(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Canada',
#        'Chile', 'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        'Denmark', 'Estonia', 'Euro area (19 countries)',
#        'European Union – 27 countries (from 01/02/2020)', 'Finland',
#        'France', 'G20', 'G7', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Latvia', 'Lithuania', 'Luxembourg', 'Mexico', 'Netherlands',
#        'New Zealand', 'Norway', 'OECD - Europe', 'OECD - Total', 'Poland',
#        'Portugal', 'Russia', 'Saudi Arabia', 'Slovak Republic',
#        'Slovenia', 'South Africa', 'South Korea', 'Spain', 'Sweden',
#        'Switzerland', 'Türkiye', 'United Kingdom', 'United States'],
#       dtype=object)

# %%
#Drop 'Euro area (19 countries)','European Union – 27 countries (from 01/02/2020)','G20', 'G7','OECD - Europe','OECD - Total',

#Fix China Korea name

# %%
df3 = df3[df3.Entity != "Euro area (19 countries)"]
df3 = df3[df3.Entity != 'European Union – 27 countries (from 01/02/2020)']
df3 = df3[df3.Entity != "G20"]
df3 = df3[df3.Entity != 'G7']
df3 = df3[df3.Entity != "OECD - Europe"]
df3 = df3[df3.Entity != 'OECD - Total']
df3 = df3[df3.Entity != 'Czech Republic']
df3 = df3[df3.Entity != 'Costa Rica']
df3 = df3[df3.Entity != 'Türkiye'] 
df3 = df3[df3.Entity != 'Slovak Republic']
df3 = df3[df3.Entity != 'Slovenia'] 
df3 = df3[df3.Entity != 'Argentina']

# df3 = df3[df3.Year != "1964"]
# df3 = df3[df3.Year != "1963"]
# df3 = df3[df3.Year != "1962"]
# df3 = df3[df3.Year != "1961"]
# df3 = df3[df3.Year != "1960"]
# df3 = df3[df3.Year != "1959"]
# df3 = df3[df3.Year != "1958"]
# df3 = df3[df3.Year != "1957"]
# df3 = df3[df3.Year != "1956"]
# df3 = df3[df3.Year != "1955"]
# df3 = df3[df3.Year != "1954"]
# df3 = df3[df3.Year != "1953"]
# df3 = df3[df3.Year != "1952"]
# df3 = df3[df3.Year != "1951"]
# df3 = df3[df3.Year != "1964"]
# df3 = df3[df3.Year != "1950"]
df3 = df3[df3.Year != "2022"]

# %%
df3 = df3.drop_duplicates(subset=['Entity', 'Year'], keep='last')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2009 entries, 0 to 2384
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    2009 non-null   object
#  1   Subject                                    2009 non-null   object
#  2   Unit                                       2009 non-null   object
#  3   Year                                       2009 non-null   object
#  4   Entity                                     2009 non-null   object
#  5   Oil (% equivalent primary energy)          2009 non-null   float64
#  6   Oil - Crude prices since 1861 (current $)  2009 non-null   float64
#  7   Coal Consumption - TWh                     2009 non-null   float64
#  8   Oil Consumption - TWh                      2009 non-null   float64
#  9   Gas Consumption - TWh                      2008 non-null   float64
# ...

# %% [markdown]
# import scipy.stats as st
# import statsmodels.api as sm
# import statsmodels.graphics.tsaplots as tsap
# from statsmodels.compat import lzip
# from statsmodels.stats.diagnostic import het_white
# from matplotlib import pyplot as plt
# import seaborn as sns

# %% [markdown]
# sns.scatterplot(x=df3['Oil (% equivalent primary energy)'],
#                 y=df3['Oil - Crude prices since 1861 (current $)'],
#                 hue=df3['Entity']).set(title=
#                 'Analyzing Inflation in relation to Oil Dependency')
#
# plt.show()

# %%
df3 = df3.sort_values(by = ['Entity', 'Year'], ascending = [True, True])

# %%
df3 = df3.reset_index(drop=True)

# %%
#df3['Exporter'] = np.where(df3['Entity']== 'Saudi Arabia' | 'Russia', 1, 0)
# df3['Exporter'] = np.where(df3['Entity']== 'Russia', 1, 0)
# df3['Exporter'] = np.where(df3['Entity']== 'Canada', 1, 0)
# df3['Exporter'] = np.where(df3['Entity']== 'United States', 1, 0)
# df3['Exporter'] = np.where(df3['Entity']== 'Norway', 1, 0)
# df3['Exporter'] = np.where(df3['Entity']== 'Brazil', 1, 0)
# df3['Exporter'] = np.where(df3['Entity']== 'Mexico', 1, 0)
# df3['Exporter'] = np.where(df3['Entity']== 'Columbia', 1, 0)
# df3['Exporter'] = np.where(df3['Entity']== 'United Kingdom', 1, 0)

df3['Exporter'] = df3["Entity"].apply(
  lambda x: "1" if x in ['Russia', "Saudi Arabia", "Canada", "United States", "Norway", "Brazil", "Mexico", "Columbia", "United Kingdom"] else '0')

# %%
#df3.drop(columns="Exporter1", inplace=True)
df3.tail(100)
# Out:
#              Country                 Subject        Unit  Year  \
# 1909  United Kingdom  CPI: 01-12 - All items  Percentage  1979
# 1910  United Kingdom  CPI: 01-12 - All items  Percentage  1980
# 1911  United Kingdom  CPI: 01-12 - All items  Percentage  1981
# 1912  United Kingdom  CPI: 01-12 - All items  Percentage  1982
# 1913  United Kingdom  CPI: 01-12 - All items  Percentage  1983
# ...              ...                     ...         ...   ...
# 2004   United States  CPI: 01-12 - All items  Percentage  2017
# 2005   United States  CPI: 01-12 - All items  Percentage  2018
# 2006   United States  CPI: 01-12 - All items  Percentage  2019
# 2007   United States  CPI: 01-12 - All items  Percentage  2020
# 2008   United States  CPI: 01-12 - All items  Percentage  2021
#
#               Entity  Oil (% equivalent primary energy)  \
# 1909  United Kingdom                          43.355740
# 1910  United Kingdom                          40.700249
# ...

# %%
df3.to_excel("Econometrics_Project_Dataset.xlsx")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (11, 5)  #set default figure size
import matplotlib
matplotlib.style.use('seaborn')

df3.mean().sort_values(ascending=False).plot(kind='bar', title="Average CPI 1965 - 2021")

#Set country labels
country_labels = df3.mean().sort_values(ascending=False).index.get_level_values('Year').tolist()
plt.xticks(range(0, len(country_labels)), country_labels)
plt.xlabel('Country')

plt.show()
# Out:
# C:\Users\ajbut\AppData\Local\Temp/ipykernel_24444/2973315156.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df3.mean().sort_values(ascending=False).plot(kind='bar', title="Average CPI 1965 - 2021")
# C:\Users\ajbut\AppData\Local\Temp/ipykernel_24444/2973315156.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   country_labels = df3.mean().sort_values(ascending=False).index.get_level_values('Year').tolist()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24444/2973315156.py in <module>
#       8
# ...

# %%
df3.describe()
# Out:
#        Oil (% equivalent primary energy)  \
# count                        2009.000000
# mean                           45.160665
# std                            15.547439
# min                            12.758014
# 25%                            34.350906
# 50%                            43.799347
# 75%                            55.336807
# max                            99.967522
#
#        Oil - Crude prices since 1861 (current $)  Coal Consumption - TWh  \
# count                                2009.000000             2009.000000
# mean                                  234.304094              623.531876
# std                                   192.720500             2210.910965
# min                                    11.320200                0.000000
# 25%                                    99.477050               23.227459
# 50%                                   173.324837               72.744568
# 75%                                   342.883120              362.361084
# ...

# %%
#pip install linearmodels

# %%
df4 = df3.drop(columns=['CPI'])
df5 = df3["CPI"]


from linearmodels import PanelOLS
from linearmodels import RandomEffects
import statsmodels.api as sm

exog = sm.tools.tools.add_constant(df4)

# random effects model
model_re = RandomEffects(df4, df5) 
re_res = model_re.fit() 

# fixed effects model
model_fe = PanelOLS(df4, df5, entity_effects = True) 
fe_res = model_fe.fit() 

#print results
print(re_res)
print(fe_res)

# %%
import datetime

# %%
df3.info()
